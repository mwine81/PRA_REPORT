# %%
import polars as pl
from polars import col as c
import polars.selectors as cs
from config import BASE_PARQUET_PATH

# %%
[print(x) for x in BASE_PARQUET_PATH.iterdir()]
# Out:
# C:\Users\mwine\Projects\AUGEST_2025\dev\PRA-FRONT-END\PRA_NEW\data\benchmark_table.parquet
# C:\Users\mwine\Projects\AUGEST_2025\dev\PRA-FRONT-END\PRA_NEW\data\hcpcs_desc_table.parquet
# C:\Users\mwine\Projects\AUGEST_2025\dev\PRA-FRONT-END\PRA_NEW\data\hospital_price_table.parquet
# C:\Users\mwine\Projects\AUGEST_2025\dev\PRA-FRONT-END\PRA_NEW\data\hospital_table.parquet
# C:\Users\mwine\Projects\AUGEST_2025\dev\PRA-FRONT-END\PRA_NEW\data\ndc_name_table.parquet
# C:\Users\mwine\Projects\AUGEST_2025\dev\PRA-FRONT-END\PRA_NEW\data\unique_lob_names.parquet
# C:\Users\mwine\Projects\AUGEST_2025\dev\PRA-FRONT-END\PRA_NEW\data\unique_plan_names.parquet
# [None, None, None, None, None, None, None]

# %%
def load_hospital_price_table() -> pl.LazyFrame:
    return pl.scan_parquet(BASE_PARQUET_PATH / "hospital_price_table.parquet")

def load_hcpcs_desc_table() -> pl.LazyFrame:
    return pl.scan_parquet(BASE_PARQUET_PATH / "hcpcs_desc_table.parquet")

def load_ndc_name_table() -> pl.LazyFrame:
    return pl.scan_parquet(BASE_PARQUET_PATH / "ndc_name_table.parquet")

def load_hospital_table() -> pl.LazyFrame:
    return pl.scan_parquet(BASE_PARQUET_PATH / "hospital_table.parquet")

def unique_hospital_ct() -> pl.Expr:
    return c.hospital_id.n_unique().alias('unique_hospital_ct')

def hcpcs_name() -> pl.Expr:
    return c.hcpcs_desc.str.split(' - ').list.get(1).str.split('[').list.get(0).alias('hcpcs_name')

def unique_type_of_measurements() -> pl.Expr:
    return cs.matches('(?i)type.*meas').str.to_lowercase().str.strip_chars().unique().alias('unique_type_of_measurements')

def calculate_price_pct() -> pl.Expr:
    return (cs.matches('(?i)calculated').sum().truediv(pl.len()).round(4)).alias('calculate_price_pct')

def price_stats() -> list[pl.Expr]:
    return (
        [
            c.standard_charge_negotiated_dollar.min().round(2).alias('min_price'),
            c.standard_charge_negotiated_dollar.max().round(2).alias('max_price'),
            c.standard_charge_negotiated_dollar.mean().round(2).alias('mean_price'),
            c.standard_charge_negotiated_dollar.std().round(2).alias('std_price'),
        ]
    )

def pct_negotiated_gt_cash() -> pl.Expr:
    # sum boolean true values and divide by total count to get percentage
    return (c.standard_charge_negotiated_dollar.gt(c.standard_charge_discounted_cash).sum().truediv(pl.len()).round(4).alias('pct_price_gt_cash_price'))

(
load_hospital_price_table()
.filter(c.hcpcs.str.starts_with('J'))
.group_by(c.hcpcs)
.agg(
    unique_hospital_ct(),
    unique_type_of_measurements(),
    unique_type_of_measurements().len().alias('unique_measure_ct'),
    calculate_price_pct(),
    *price_stats(),
    pct_negotiated_gt_cash(),

)
.join(load_hcpcs_desc_table(), on='hcpcs')
.with_columns(hcpcs_name())
.head(10)
.collect(engine='streaming')
.to_pandas()
)
# Out:
#    hcpcs  unique_hospital_ct            unique_type_of_measurements  \
# 0  J9209                 466      [gram, unit, ml, ea, me, unknown]
# 1  J2792                 283  [unit, unknown, gram, me, ml, f2, ea]
# 2  J3315                 265            [unit, ml, ea, me, unknown]
# 3  J3095                 238            [unit, unknown, ea, me, ml]
# 4  J1645                 239            [f2, unknown, ml, ea, unit]
# 5  J2798                 202            [me, ea, unit, ml, unknown]
# 6  J1302                 183                      [me, unknown, ml]
# 7  J2356                 310            [unknown, unit, ml, me, ea]
# 8  J0517                 425      [ml, me, gram, ea, unit, unknown]
# 9  J7503                 226                [unit, unknown, me, ea]
#
#    unique_measure_ct  calculate_price_pct  min_price     max_price  \
# 0                  6               0.3655       0.00  1.300000e+04
# 1                  7               0.3882       0.01  5.589325e+04
# 2                  5               0.2407       0.01  3.243650e+04
# 3                  5               0.2751       0.01  1.334720e+05
# 4                  5               0.2531       0.01  2.836200e+04
# 5                  5               0.0263       1.55  4.327554e+04
# 6                  3               0.1812       0.01  2.598863e+04
# 7                  5               0.4160       0.01  6.192250e+05
# 8                  6               0.3774       0.01  1.000000e+10
# 9                  4               0.3933       0.01  4.463200e+03
#
#    mean_price    std_price  pct_price_gt_cash_price  \
# 0       98.55       228.83                   0.3372
# 1     1756.01      4232.95                   0.3324
# 2     2557.16      3481.87                   0.3252
# 3     1205.16      8575.58                   0.3693
# 4      208.99       535.24                   0.3530
# 5      907.11      2719.09                   0.3255
# 6     1664.07      3277.35                   0.3028
# 7     5070.20      7774.97                   0.3330
# 8   497816.93  69707097.28                   0.3126
# 9      212.40       567.51                   0.2787
#
#                                           hcpcs_desc  \
# 0            J9209 - Mesna injection [Mesna, Mesnex]
# 1  J2792 - Rho(d) immune globulin h, sd [Rho, Win...
# 2  J3315 - Triptorelin pamoate [Trelstar, Triptor...
# 3  J3095 - Telavancin injection [Telavancin, Viba...
# 4    J1645 - Dalteparin sodium [Dalteparin, Fragmin]
# 5  J2798 - Inj., perseris, 0.5 mg [Perseris, Risp...
# 6  J1302 - Inj, sutimlimab-jome, 10 mg [Enjaymo, ...
# 7  J2356 - Inj tezepelumab-ekko, 1mg [Tezepelumab...
# 8  J0517 - Inj., benralizumab, 1 mg [Benralizumab...
# 9  J7503 - Tacrol envarsus ex rel oral [Envarsus,...
#
#                       hcpcs_name
# 0               Mesna injection
# 1  Rho(d) immune globulin h, sd
# 2           Triptorelin pamoate
# 3          Telavancin injection
# 4             Dalteparin sodium
# 5        Inj., perseris, 0.5 mg
# 6   Inj, sutimlimab-jome, 10 mg
# 7     Inj tezepelumab-ekko, 1mg
# 8      Inj., benralizumab, 1 mg
# 9   Tacrol envarsus ex rel oral

# %%
(
load_hospital_price_table()
.head()
.collect(engine='streaming')
.to_pandas()
)
# Out:
#                             hospital_id                    description  \
# 0  00117837-839b-4714-98d0-4395a91d8d9a  BUMETANIDE 0.25 MG/ML IJ SOLN
# 1  00117837-839b-4714-98d0-4395a91d8d9a  BUMETANIDE 0.25 MG/ML IJ SOLN
# 2  00117837-839b-4714-98d0-4395a91d8d9a  BUMETANIDE 0.25 MG/ML IJ SOLN
# 3  00117837-839b-4714-98d0-4395a91d8d9a  BUMETANIDE 0.25 MG/ML IJ SOLN
# 4  00117837-839b-4714-98d0-4395a91d8d9a  BUMETANIDE 0.25 MG/ML IJ SOLN
#
#       setting  drug_unit_of_measurement drug_type_of_measurement  \
# 0  outpatient                       2.0                       ml
# 1  outpatient                       2.0                       ml
# 2  outpatient                       2.0                       ml
# 3  outpatient                       2.0                       ml
# 4  outpatient                       2.0                       ml
#
#    standard_charge_gross  standard_charge_discounted_cash  \
# 0                   75.0                             45.0
# 1                   75.0                             45.0
# 2                   75.0                             45.0
# 3                   75.0                             45.0
# 4                   75.0                             45.0
#
#    standard_charge_negotiated_dollar plan_name  \
# 0                               1.44       PPO
# 1                              22.80       PPO
# 2                              13.75       HMO
# 3                              22.80       HMO
# 4                              13.27       PPO
#
#                              payer_name      standard_charge_methodology  \
# 0  UNITED_HEALTHCARE_CHOICE_PLU_3112014                     fee schedule
# 1                         CIGNA_3020001  percent of total billed charges
# 2           SENTARA_VANTAGE_HMO_4984001  percent of total billed charges
# 3            CIGNA_FLEXCARE_HMO_3020048  percent of total billed charges
# 4                         AETNA_3004001  percent of total billed charges
#
#    standard_charge_negotiated_percentage  hcpcs          ndc  \
# 0                                    NaN  J1939  68462046954
# 1                                  30.40  J1939  68462046954
# 2                                  18.33  J1939  68462046954
# 3                                  30.40  J1939  68462046954
# 4                                  17.70  J1939  68462046954
#
#    calculated_negotiated_dollars    mapped_plan_name mapped_lob_name
# 0                          False  United Health Care            None
# 1                           True               Cigna            None
# 2                           True             Vantage            None
# 3                           True               Cigna            None
# 4                           True               Aetna            None

# %%
(
load_hospital_price_table()
.filter(c.ndc.is_not_null())
.join(load_ndc_name_table(), on='ndc')
.group_by(c.product)
.agg(
    unique_hospital_ct(),
    unique_type_of_measurements(),
    unique_type_of_measurements().len().alias('unique_measure_ct'),
    calculate_price_pct(),
)
.collect(engine='streaming')
.sort('unique_hospital_ct', descending=True)
.to_pandas()
.head(10)
)
# Out:
#                                            product  unique_hospital_ct  \
# 0                       Eliquis Oral Tablet 2.5 MG                 349
# 1                         Eliquis Oral Tablet 5 MG                 346
# 2                    Entresto Oral Tablet 24-26 MG                 330
# 3                        Xarelto Oral Tablet 10 MG                 325
# 4                       Xifaxan Oral Tablet 550 MG                 307
# 5                    Entresto Oral Tablet 49-51 MG                 280
# 6           HumaLOG Injection Solution 100 UNIT/ML                 275
# 7    Cyanocobalamin Injection Solution 1000 MCG/ML                 275
# 8                      Jardiance Oral Tablet 10 MG                 274
# 9  diphenhydrAMINE HCl Injection Solution 50 MG/ML                 273
#
#          unique_type_of_measurements  unique_measure_ct  calculate_price_pct
# 0           [ml, ea, gram, unit, me]                  5               0.4457
# 1  [gram, unit, unknown, me, ml, ea]                  6               0.4910
# 2  [unit, unknown, me, gram, ml, ea]                  6               0.4441
# 3               [unit, me, ea, gram]                  4               0.5996
# 4            [unit, ea, me, unknown]                  4               0.6033
# 5  [ml, gram, ea, unit, me, unknown]                  6               0.4480
# 6                     [unit, ea, ml]                  3               0.4305
# 7           [ml, me, ea, unit, gram]                  5               0.2943
# 8               [gram, me, ea, unit]                  4               0.5955
# 9           [gram, ea, me, unit, ml]                  5               0.3385
